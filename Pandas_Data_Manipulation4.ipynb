# %% [markdown]
# # Combining Dataframes using merge()

# %%
import pandas as pd

# %%
# Read the dataset
data=pd.read_csv('bigmart_data.csv')

# %%
# Counting the number of rows and columns of the dataframe.
data_rows = len(data.index)
data_columns = len(data.columns)
data_rows, data_columns
# Out:
# (8523, 12)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Splitting the data
data_part1 = data[:100]
data_part2 = data[100:200]

# %%
data_part1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data_part2.head()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 100           FDT28        13.30          Low Fat         0.063695
# 101           FDD10          NaN          Regular         0.045798
# 102           FDW57         8.31          Regular         0.115857
# 103           DRB48        16.75          Regular         0.024833
# 104           FDP09        19.75          Low Fat         0.034028
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 100  Frozen Foods  151.0708            OUT045                       2002
# 101   Snack Foods  178.5344            OUT027                       1985
# 102   Snack Foods  179.1028            OUT049                       1999
# 103   Soft Drinks   38.7822            OUT013                       1987
# 104   Snack Foods  212.0902            OUT018                       2009
#
#     Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 100         NaN               Tier 2  Supermarket Type1          1805.6496
# 101      Medium               Tier 3  Supermarket Type3          2854.9504
# 102      Medium               Tier 1  Supermarket Type1          3896.2616
# 103        High               Tier 3  Supermarket Type1           667.7974
# 104      Medium               Tier 3  Supermarket Type2          3185.8530

# %%
data_part1_rows = len(data_part1.index)
data_part1_columns = len(data_part1.columns)
data_part1_rows, data_part1_columns
# Out:
# (100, 12)

# %%
data_part2_rows = len(data_part2.index)
data_part2_columns = len(data_part2.columns)
data_part2_rows, data_part2_columns
# Out:
# (100, 12)

# %%
# Merging dataframes with merge() and join='outer'
combined_data1 = pd.merge(data_part1, data_part2, on='Item_Fat_Content', how='outer')
combined_data1
# Out:
#      Item_Identifier_x  Item_Weight_x Item_Fat_Content  Item_Visibility_x  \
# 0                FDA15           9.30          Low Fat           0.016047
# 1                FDA15           9.30          Low Fat           0.016047
# 2                FDA15           9.30          Low Fat           0.016047
# 3                FDA15           9.30          Low Fat           0.016047
# 4                FDA15           9.30          Low Fat           0.016047
# ...                ...            ...              ...                ...
# 4733             FDM39           6.42               LF           0.089499
# 4734             FDC46          17.70               LF           0.195068
# 4735             FDC46          17.70               LF           0.195068
# 4736             FDN04          11.80              reg           0.014087
# 4737             FDN04          11.80              reg           0.014087
#
#        Item_Type_x  Item_MRP_x Outlet_Identifier_x  \
# 0            Dairy    249.8092              OUT049
# 1            Dairy    249.8092              OUT049
# 2            Dairy    249.8092              OUT049
# 3            Dairy    249.8092              OUT049
# 4            Dairy    249.8092              OUT049
# ...            ...         ...                 ...
# 4733         Dairy    178.1002              OUT010
# 4734   Snack Foods    185.4266              OUT010
# 4735   Snack Foods    185.4266              OUT010
# 4736  Frozen Foods    180.3344              OUT046
# 4737  Frozen Foods    180.3344              OUT046
#
#       Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                            1999        Medium                 Tier 1  ...
# 1                            1999        Medium                 Tier 1  ...
# 2                            1999        Medium                 Tier 1  ...
# 3                            1999        Medium                 Tier 1  ...
# 4                            1999        Medium                 Tier 1  ...
# ...                           ...           ...                    ...  ...
# 4733                         1998           NaN                 Tier 3  ...
# 4734                         1998           NaN                 Tier 3  ...
# 4735                         1998           NaN                 Tier 3  ...
# 4736                         1997         Small                 Tier 1  ...
# 4737                         1997         Small                 Tier 1  ...
#
#      Item_Weight_y  Item_Visibility_y   Item_Type_y  Item_MRP_y  \
# 0            13.30           0.063695  Frozen Foods    151.0708
# 1            19.75           0.034028   Snack Foods    212.0902
# 2            14.15           0.035914   Soft Drinks     41.4138
# 3            13.30           0.079806         Dairy    232.5300
# 4              NaN           0.071637   Snack Foods    121.7098
# ...            ...                ...           ...         ...
# 4733         17.85           0.000000        Breads    196.5794
# 4734         12.65           0.063018   Soft Drinks    159.0578
# 4735         17.85           0.000000        Breads    196.5794
# 4736         13.85           0.026002  Frozen Foods    161.5210
# 4737           NaN           0.101339        Canned    232.6300
#
#       Outlet_Identifier_y Outlet_Establishment_Year_y  Outlet_Size_y  \
# 0                  OUT045                        2002            NaN
# 1                  OUT018                        2009         Medium
# 2                  OUT013                        1987           High
# 3                  OUT046                        1997          Small
# 4                  OUT027                        1985         Medium
# ...                   ...                         ...            ...
# 4733               OUT010                        1998            NaN
# 4734               OUT045                        2002            NaN
# 4735               OUT010                        1998            NaN
# 4736               OUT018                        2009         Medium
# 4737               OUT027                        1985         Medium
#
#      Outlet_Location_Type_y      Outlet_Type_y Item_Outlet_Sales_y
# 0                    Tier 2  Supermarket Type1           1805.6496
# 1                    Tier 3  Supermarket Type2           3185.8530
# 2                    Tier 3  Supermarket Type1            812.2760
# 3                    Tier 1  Supermarket Type1            699.0900
# 4                    Tier 3  Supermarket Type3           4097.3332
# ...                     ...                ...                 ...
# 4733                 Tier 3      Grocery Store            585.2382
# 4734                 Tier 2  Supermarket Type1           2085.9514
# 4735                 Tier 3      Grocery Store            585.2382
# 4736                 Tier 3  Supermarket Type2           1794.3310
# 4737                 Tier 3  Supermarket Type3           5359.6900
#
# [4738 rows x 23 columns]

# %%
combined_data1_rows = len(combined_data1.index)
combined_data1_columns = len(combined_data1.columns)
combined_data1_rows, combined_data1_columns
# Out:
# (4738, 23)

# %%
# Merging dataframes with merge() and join='inner'
combined_data2 = pd.merge(data_part1, data_part2, on='Item_Fat_Content', how='inner')
combined_data2
# Out:
#      Item_Identifier_x  Item_Weight_x Item_Fat_Content  Item_Visibility_x  \
# 0                FDA15           9.30          Low Fat           0.016047
# 1                FDA15           9.30          Low Fat           0.016047
# 2                FDA15           9.30          Low Fat           0.016047
# 3                FDA15           9.30          Low Fat           0.016047
# 4                FDA15           9.30          Low Fat           0.016047
# ...                ...            ...              ...                ...
# 4733             FDM39           6.42               LF           0.089499
# 4734             FDC46          17.70               LF           0.195068
# 4735             FDC46          17.70               LF           0.195068
# 4736             FDN04          11.80              reg           0.014087
# 4737             FDN04          11.80              reg           0.014087
#
#        Item_Type_x  Item_MRP_x Outlet_Identifier_x  \
# 0            Dairy    249.8092              OUT049
# 1            Dairy    249.8092              OUT049
# 2            Dairy    249.8092              OUT049
# 3            Dairy    249.8092              OUT049
# 4            Dairy    249.8092              OUT049
# ...            ...         ...                 ...
# 4733         Dairy    178.1002              OUT010
# 4734   Snack Foods    185.4266              OUT010
# 4735   Snack Foods    185.4266              OUT010
# 4736  Frozen Foods    180.3344              OUT046
# 4737  Frozen Foods    180.3344              OUT046
#
#       Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                            1999        Medium                 Tier 1  ...
# 1                            1999        Medium                 Tier 1  ...
# 2                            1999        Medium                 Tier 1  ...
# 3                            1999        Medium                 Tier 1  ...
# 4                            1999        Medium                 Tier 1  ...
# ...                           ...           ...                    ...  ...
# 4733                         1998           NaN                 Tier 3  ...
# 4734                         1998           NaN                 Tier 3  ...
# 4735                         1998           NaN                 Tier 3  ...
# 4736                         1997         Small                 Tier 1  ...
# 4737                         1997         Small                 Tier 1  ...
#
#      Item_Weight_y  Item_Visibility_y   Item_Type_y  Item_MRP_y  \
# 0            13.30           0.063695  Frozen Foods    151.0708
# 1            19.75           0.034028   Snack Foods    212.0902
# 2            14.15           0.035914   Soft Drinks     41.4138
# 3            13.30           0.079806         Dairy    232.5300
# 4              NaN           0.071637   Snack Foods    121.7098
# ...            ...                ...           ...         ...
# 4733         17.85           0.000000        Breads    196.5794
# 4734         12.65           0.063018   Soft Drinks    159.0578
# 4735         17.85           0.000000        Breads    196.5794
# 4736         13.85           0.026002  Frozen Foods    161.5210
# 4737           NaN           0.101339        Canned    232.6300
#
#       Outlet_Identifier_y Outlet_Establishment_Year_y  Outlet_Size_y  \
# 0                  OUT045                        2002            NaN
# 1                  OUT018                        2009         Medium
# 2                  OUT013                        1987           High
# 3                  OUT046                        1997          Small
# 4                  OUT027                        1985         Medium
# ...                   ...                         ...            ...
# 4733               OUT010                        1998            NaN
# 4734               OUT045                        2002            NaN
# 4735               OUT010                        1998            NaN
# 4736               OUT018                        2009         Medium
# 4737               OUT027                        1985         Medium
#
#      Outlet_Location_Type_y      Outlet_Type_y Item_Outlet_Sales_y
# 0                    Tier 2  Supermarket Type1           1805.6496
# 1                    Tier 3  Supermarket Type2           3185.8530
# 2                    Tier 3  Supermarket Type1            812.2760
# 3                    Tier 1  Supermarket Type1            699.0900
# 4                    Tier 3  Supermarket Type3           4097.3332
# ...                     ...                ...                 ...
# 4733                 Tier 3      Grocery Store            585.2382
# 4734                 Tier 2  Supermarket Type1           2085.9514
# 4735                 Tier 3      Grocery Store            585.2382
# 4736                 Tier 3  Supermarket Type2           1794.3310
# 4737                 Tier 3  Supermarket Type3           5359.6900
#
# [4738 rows x 23 columns]

# %%
combined_data2_rows = len(combined_data2.index)
combined_data2_columns = len(combined_data2.columns)
combined_data2_rows, combined_data2_columns
# Out:
# (4738, 23)

# %%
# Merging dataframes with merge() and join='outer'
combined_data3 = pd.merge(data_part1, data_part2, on='Item_Type', how='outer')
combined_data3
# Out:
#     Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0               FDA15           9.30            Low Fat           0.016047
# 1               FDA15           9.30            Low Fat           0.016047
# 2               FDA15           9.30            Low Fat           0.016047
# 3               FDA15           9.30            Low Fat           0.016047
# 4               FDA15           9.30            Low Fat           0.016047
# ..                ...            ...                ...                ...
# 845             FDH35          18.25            Low Fat           0.000000
# 846               NaN            NaN                NaN                NaN
# 847               NaN            NaN                NaN                NaN
# 848               NaN            NaN                NaN                NaN
# 849               NaN            NaN                NaN                NaN
#
#          Item_Type  Item_MRP_x Outlet_Identifier_x  \
# 0            Dairy    249.8092              OUT049
# 1            Dairy    249.8092              OUT049
# 2            Dairy    249.8092              OUT049
# 3            Dairy    249.8092              OUT049
# 4            Dairy    249.8092              OUT049
# ..             ...         ...                 ...
# 845  Starchy Foods    164.7526              OUT045
# 846         Others         NaN                 NaN
# 847         Others         NaN                 NaN
# 848         Others         NaN                 NaN
# 849         Others         NaN                 NaN
#
#      Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                         1999.0        Medium                 Tier 1  ...
# 1                         1999.0        Medium                 Tier 1  ...
# 2                         1999.0        Medium                 Tier 1  ...
# 3                         1999.0        Medium                 Tier 1  ...
# 4                         1999.0        Medium                 Tier 1  ...
# ..                           ...           ...                    ...  ...
# 845                       2002.0           NaN                 Tier 2  ...
# 846                          NaN           NaN                    NaN  ...
# 847                          NaN           NaN                    NaN  ...
# 848                          NaN           NaN                    NaN  ...
# 849                          NaN           NaN                    NaN  ...
#
#     Item_Weight_y  Item_Fat_Content_y Item_Visibility_y  Item_MRP_y  \
# 0           13.30             Low Fat          0.079806    232.5300
# 1           19.25             Low Fat          0.102350     52.7956
# 2            6.92             Low Fat          0.038532     60.5852
# 3            5.75             Regular          0.075108    112.8176
# 4             NaN             Regular          0.098664     62.9194
# ..            ...                 ...               ...         ...
# 845         12.30             Regular          0.064750     92.6804
# 846         18.50             Low Fat          0.056816    132.1284
# 847         12.80             Low Fat          0.091222    105.5938
# 848         14.50             Low Fat          0.019472    164.8210
# 849         14.60             Low Fat          0.059583    238.8538
#
#     Outlet_Identifier_y  Outlet_Establishment_Year_y  Outlet_Size_y  \
# 0                OUT046                         1997          Small
# 1                OUT017                         2007            NaN
# 2                OUT045                         2002            NaN
# 3                OUT013                         1987           High
# 4                OUT027                         1985         Medium
# ..                  ...                          ...            ...
# 845              OUT045                         2002            NaN
# 846              OUT010                         1998            NaN
# 847              OUT045                         2002            NaN
# 848              OUT035                         2004          Small
# 849              OUT049                         1999         Medium
#
#     Outlet_Location_Type_y      Outlet_Type_y Item_Outlet_Sales_y
# 0                   Tier 1  Supermarket Type1            699.0900
# 1                   Tier 2  Supermarket Type1            928.1252
# 2                   Tier 2  Supermarket Type1           1314.2892
# 3                   Tier 3  Supermarket Type1           1374.2112
# 4                   Tier 3  Supermarket Type3           2105.2596
# ..                     ...                ...                 ...
# 845                 Tier 2  Supermarket Type1           1010.6844
# 846                 Tier 3      Grocery Store            263.6568
# 847                 Tier 2  Supermarket Type1           2143.8760
# 848                 Tier 2  Supermarket Type1           2120.5730
# 849                 Tier 1  Supermarket Type1           6008.8450
#
# [850 rows x 23 columns]

# %%
combined_data3_rows = len(combined_data3.index)
combined_data3_columns = len(combined_data3.columns)
combined_data3_rows, combined_data3_columns
# Out:
# (850, 23)

# %%
# Merging dataframes with merge() and join='inner'
combined_data4 = pd.merge(data_part1, data_part2, on='Item_Type', how='inner')
combined_data4
# Out:
#     Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0               FDA15           9.30            Low Fat           0.016047
# 1               FDA15           9.30            Low Fat           0.016047
# 2               FDA15           9.30            Low Fat           0.016047
# 3               FDA15           9.30            Low Fat           0.016047
# 4               FDA15           9.30            Low Fat           0.016047
# ..                ...            ...                ...                ...
# 841             FDO23          17.85            Low Fat           0.000000
# 842             FDO23          17.85            Low Fat           0.000000
# 843             FDH35          18.25            Low Fat           0.000000
# 844             FDH35          18.25            Low Fat           0.000000
# 845             FDH35          18.25            Low Fat           0.000000
#
#          Item_Type  Item_MRP_x Outlet_Identifier_x  \
# 0            Dairy    249.8092              OUT049
# 1            Dairy    249.8092              OUT049
# 2            Dairy    249.8092              OUT049
# 3            Dairy    249.8092              OUT049
# 4            Dairy    249.8092              OUT049
# ..             ...         ...                 ...
# 841         Breads     93.1436              OUT045
# 842         Breads     93.1436              OUT045
# 843  Starchy Foods    164.7526              OUT045
# 844  Starchy Foods    164.7526              OUT045
# 845  Starchy Foods    164.7526              OUT045
#
#      Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                           1999        Medium                 Tier 1  ...
# 1                           1999        Medium                 Tier 1  ...
# 2                           1999        Medium                 Tier 1  ...
# 3                           1999        Medium                 Tier 1  ...
# 4                           1999        Medium                 Tier 1  ...
# ..                           ...           ...                    ...  ...
# 841                         2002           NaN                 Tier 2  ...
# 842                         2002           NaN                 Tier 2  ...
# 843                         2002           NaN                 Tier 2  ...
# 844                         2002           NaN                 Tier 2  ...
# 845                         2002           NaN                 Tier 2  ...
#
#     Item_Weight_y  Item_Fat_Content_y Item_Visibility_y  Item_MRP_y  \
# 0           13.30             Low Fat          0.079806    232.5300
# 1           19.25             Low Fat          0.102350     52.7956
# 2            6.92             Low Fat          0.038532     60.5852
# 3            5.75             Regular          0.075108    112.8176
# 4             NaN             Regular          0.098664     62.9194
# ..            ...                 ...               ...         ...
# 841         12.60             Low Fat          0.048981     61.9194
# 842         17.85                  LF          0.000000    196.5794
# 843           NaN             Low Fat          0.059957    165.4526
# 844         16.00             Low Fat          0.060837    226.8404
# 845         12.30             Regular          0.064750     92.6804
#
#     Outlet_Identifier_y  Outlet_Establishment_Year_y  Outlet_Size_y  \
# 0                OUT046                         1997          Small
# 1                OUT017                         2007            NaN
# 2                OUT045                         2002            NaN
# 3                OUT013                         1987           High
# 4                OUT027                         1985         Medium
# ..                  ...                          ...            ...
# 841              OUT018                         2009         Medium
# 842              OUT010                         1998            NaN
# 843              OUT027                         1985         Medium
# 844              OUT035                         2004          Small
# 845              OUT045                         2002            NaN
#
#     Outlet_Location_Type_y      Outlet_Type_y Item_Outlet_Sales_y
# 0                   Tier 1  Supermarket Type1            699.0900
# 1                   Tier 2  Supermarket Type1            928.1252
# 2                   Tier 2  Supermarket Type1           1314.2892
# 3                   Tier 3  Supermarket Type1           1374.2112
# 4                   Tier 3  Supermarket Type3           2105.2596
# ..                     ...                ...                 ...
# 841                 Tier 3  Supermarket Type2            619.1940
# 842                 Tier 3      Grocery Store            585.2382
# 843                 Tier 3  Supermarket Type3           5262.4832
# 844                 Tier 2  Supermarket Type1           6301.1312
# 845                 Tier 2  Supermarket Type1           1010.6844
#
# [846 rows x 23 columns]

# %%
combined_data4_rows = len(combined_data4.index)
combined_data4_columns = len(combined_data4.columns)
combined_data4_rows, combined_data4_columns
# Out:
# (846, 23)

# %%
# Note that data_part1 and data_part2 have the same shared keys on 'Item_Fat_Content'.
# But this is not the case on 'Item_Type'.
# So joining 'outer' and 'inner' causes differnt effects.
# There are some keys that either of the data_part1 or data_par2 don't have.
shared_keys1 = combined_data1_rows - combined_data2_rows
shared_keys2 = combined_data3_rows - combined_data4_rows
shared_keys1, shared_keys2
# Out:
# (0, 4)

# %%
# Finding these different keys:
item_type_keys_of_data_part1 = data_part1['Item_Type'].unique()
item_type_keys_of_data_part1
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods'], dtype=object)

# %%
len(item_type_keys_of_data_part1)
# Out:
# 14

# %%
item_type_keys_of_data_part2 = data_part2['Item_Type'].unique()
item_type_keys_of_data_part2
# Out:
# array(['Frozen Foods', 'Snack Foods', 'Soft Drinks', 'Canned',
#        'Baking Goods', 'Dairy', 'Meat', 'Breads', 'Household',
#        'Hard Drinks', 'Health and Hygiene', 'Starchy Foods',
#        'Fruits and Vegetables', 'Others', 'Breakfast'], dtype=object)

# %%
len(item_type_keys_of_data_part2)
# Out:
# 15

# %%
for item1 in item_type_keys_of_data_part1:
    for item2 in item_type_keys_of_data_part2:
        if item1 == item2:
            print(item1)
# Out:
# Dairy
# Soft Drinks
# Meat
# Fruits and Vegetables
# Household
# Baking Goods
# Snack Foods
# Frozen Foods
# Breakfast
# Health and Hygiene
# Hard Drinks
# Canned
# Breads
# Starchy Foods

# %%
for item2 in item_type_keys_of_data_part2:
    for item1 in item_type_keys_of_data_part1:
        if item2 == item1:
            print(item2)
# Out:
# Frozen Foods
# Snack Foods
# Soft Drinks
# Canned
# Baking Goods
# Dairy
# Meat
# Breads
# Household
# Hard Drinks
# Health and Hygiene
# Starchy Foods
# Fruits and Vegetables
# Breakfast

# %%
for item1 in item_type_keys_of_data_part1:
    if item1 not in item_type_keys_of_data_part2:
        print('!!!>>> "{}" is not present in data_part2<<<!!!'.format(item1))
    else: print('"{}" is present in data_part2.'.format(item1))
# Out:
# "Dairy" is present in data_part2.
# "Soft Drinks" is present in data_part2.
# "Meat" is present in data_part2.
# "Fruits and Vegetables" is present in data_part2.
# "Household" is present in data_part2.
# "Baking Goods" is present in data_part2.
# "Snack Foods" is present in data_part2.
# "Frozen Foods" is present in data_part2.
# "Breakfast" is present in data_part2.
# "Health and Hygiene" is present in data_part2.
# "Hard Drinks" is present in data_part2.
# "Canned" is present in data_part2.
# "Breads" is present in data_part2.
# "Starchy Foods" is present in data_part2.

# %%
# 'Others' is present in data_part2, but absent in data_part1.
for item2 in item_type_keys_of_data_part2:
    if item2 not in item_type_keys_of_data_part1:
        print('!!!>>> "{}" is not present in data_part1 <<<!!!'.format(item2))
    else: print('"{}" is present in data_part1.'.format(item2))
# Out:
# "Frozen Foods" is present in data_part1.
# "Snack Foods" is present in data_part1.
# "Soft Drinks" is present in data_part1.
# "Canned" is present in data_part1.
# "Baking Goods" is present in data_part1.
# "Dairy" is present in data_part1.
# "Meat" is present in data_part1.
# "Breads" is present in data_part1.
# "Household" is present in data_part1.
# "Hard Drinks" is present in data_part1.
# "Health and Hygiene" is present in data_part1.
# "Starchy Foods" is present in data_part1.
# "Fruits and Vegetables" is present in data_part1.
# !!!>>> "Others" is not present in data_part1 <<<!!!
# "Breakfast" is present in data_part1.

# %%
# So 4 samples with 'Item_Type'='Others' are present in data_part2 that are absent in data_part1.
# These 4 samples point to the difference between join innerly and outerly, i.e. shared_keys2=4.
data_part2[data_part2['Item_Type'].str.match('Others')]
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 139           NCN07         18.5          Low Fat         0.056816    Others
# 142           NCO55         12.8          Low Fat         0.091222    Others
# 170           NCM43         14.5          Low Fat         0.019472    Others
# 197           NCN55         14.6          Low Fat         0.059583    Others
#
#      Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 139  132.1284            OUT010                       1998         NaN
# 142  105.5938            OUT045                       2002         NaN
# 170  164.8210            OUT035                       2004       Small
# 197  238.8538            OUT049                       1999      Medium
#
#     Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 139               Tier 3      Grocery Store           263.6568
# 142               Tier 2  Supermarket Type1          2143.8760
# 170               Tier 2  Supermarket Type1          2120.5730
# 197               Tier 1  Supermarket Type1          6008.8450

# %%
# Merging dataframes with merge() and join='inner'
# In this case, data_part1 and data_part2 only have one shared key, namely 'Item_MRP' = 222.5456.  
combined_data5 = pd.merge(data_part1, data_part2, on='Item_MRP', how='inner')
combined_data5
# Out:
#   Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0             FDV25          5.905            Low Fat                0.0
#
#   Item_Type_x  Item_MRP Outlet_Identifier_x  Outlet_Establishment_Year_x  \
# 0      Canned  222.5456              OUT045                         2002
#
#   Outlet_Size_x Outlet_Location_Type_x  ... Item_Weight_y  Item_Fat_Content_y  \
# 0           NaN                 Tier 2  ...         5.905             Low Fat
#
#   Item_Visibility_y  Item_Type_y Outlet_Identifier_y  \
# 0          0.045838       Canned              OUT018
#
#    Outlet_Establishment_Year_y Outlet_Size_y Outlet_Location_Type_y  \
# 0                         2009        Medium                 Tier 3
#
#        Outlet_Type_y Item_Outlet_Sales_y
# 0  Supermarket Type2            3315.684
#
# [1 rows x 23 columns]

# %%
combined_data5_rows = len(combined_data5.index)
combined_data5_columns = len(combined_data5.columns)
combined_data5_rows, combined_data5_columns
# Out:
# (1, 23)

# %%
# And when we join the data parts outerly, we don't miss any data.
combined_data6 = pd.merge(data_part1, data_part2, on='Item_MRP', how='outer')
combined_data6
# Out:
#     Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0               FDA15           9.30            Low Fat           0.016047
# 1               DRC01           5.92            Regular           0.019278
# 2               FDN15          17.50            Low Fat           0.016760
# 3               FDX07          19.20            Regular           0.000000
# 4               NCD19           8.93            Low Fat           0.000000
# ..                ...            ...                ...                ...
# 194               NaN            NaN                NaN                NaN
# 195               NaN            NaN                NaN                NaN
# 196               NaN            NaN                NaN                NaN
# 197               NaN            NaN                NaN                NaN
# 198               NaN            NaN                NaN                NaN
#
#                Item_Type_x  Item_MRP Outlet_Identifier_x  \
# 0                    Dairy  249.8092              OUT049
# 1              Soft Drinks   48.2692              OUT018
# 2                     Meat  141.6180              OUT049
# 3    Fruits and Vegetables  182.0950              OUT010
# 4                Household   53.8614              OUT013
# ..                     ...       ...                 ...
# 194                    NaN   37.6164                 NaN
# 195                    NaN   48.0718                 NaN
# 196                    NaN  238.8538                 NaN
# 197                    NaN   62.9194                 NaN
# 198                    NaN  232.6300                 NaN
#
#      Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                         1999.0        Medium                 Tier 1  ...
# 1                         2009.0        Medium                 Tier 3  ...
# 2                         1999.0        Medium                 Tier 1  ...
# 3                         1998.0           NaN                 Tier 3  ...
# 4                         1987.0          High                 Tier 3  ...
# ..                           ...           ...                    ...  ...
# 194                          NaN           NaN                    NaN  ...
# 195                          NaN           NaN                    NaN  ...
# 196                          NaN           NaN                    NaN  ...
# 197                          NaN           NaN                    NaN  ...
# 198                          NaN           NaN                    NaN  ...
#
#     Item_Weight_y  Item_Fat_Content_y Item_Visibility_y  \
# 0             NaN                 NaN               NaN
# 1             NaN                 NaN               NaN
# 2             NaN                 NaN               NaN
# 3             NaN                 NaN               NaN
# 4             NaN                 NaN               NaN
# ..            ...                 ...               ...
# 194          10.5             Low Fat          0.041395
# 195          19.0             Regular          0.097313
# 196          14.6             Low Fat          0.059583
# 197           NaN             Regular          0.098664
# 198           NaN                 reg          0.101339
#
#                Item_Type_y Outlet_Identifier_y  Outlet_Establishment_Year_y  \
# 0                      NaN                 NaN                          NaN
# 1                      NaN                 NaN                          NaN
# 2                      NaN                 NaN                          NaN
# 3                      NaN                 NaN                          NaN
# 4                      NaN                 NaN                          NaN
# ..                     ...                 ...                          ...
# 194  Fruits and Vegetables              OUT046                       1997.0
# 195           Frozen Foods              OUT046                       1997.0
# 196                 Others              OUT049                       1999.0
# 197                  Dairy              OUT027                       1985.0
# 198                 Canned              OUT027                       1985.0
#
#     Outlet_Size_y Outlet_Location_Type_y      Outlet_Type_y  \
# 0             NaN                    NaN                NaN
# 1             NaN                    NaN                NaN
# 2             NaN                    NaN                NaN
# 3             NaN                    NaN                NaN
# 4             NaN                    NaN                NaN
# ..            ...                    ...                ...
# 194         Small                 Tier 1  Supermarket Type1
# 195         Small                 Tier 1  Supermarket Type1
# 196        Medium                 Tier 1  Supermarket Type1
# 197        Medium                 Tier 3  Supermarket Type3
# 198        Medium                 Tier 3  Supermarket Type3
#
#     Item_Outlet_Sales_y
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 194            540.6296
# 195            992.7078
# 196           6008.8450
# 197           2105.2596
# 198           5359.6900
#
# [199 rows x 23 columns]

# %%
# 199 = 99 different 'Item_MRP's of data_part1 + 99 different 'Item_MRP's of data_part2 + 1 shared key (Item_MRP' = 222.5456) 
combined_data6_rows = len(combined_data6.index)
combined_data6_columns = len(combined_data6.columns)
combined_data6_rows, combined_data6_columns
# Out:
# (199, 23)

# %%
# Merging dataframes with merge() and join='left'
combined_data7 = pd.merge(data_part1, data_part2, on='Item_MRP', how='left')
combined_data7
# Out:
#    Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0              FDA15           9.30            Low Fat           0.016047
# 1              DRC01           5.92            Regular           0.019278
# 2              FDN15          17.50            Low Fat           0.016760
# 3              FDX07          19.20            Regular           0.000000
# 4              NCD19           8.93            Low Fat           0.000000
# ..               ...            ...                ...                ...
# 95             FDU04            NaN            Low Fat           0.009715
# 96             FDF41          12.15            Low Fat           0.131384
# 97             FDB56           8.75            Regular           0.074613
# 98             NCP18            NaN            Low Fat           0.028460
# 99             FDB56           8.75            Regular           0.074627
#
#               Item_Type_x  Item_MRP Outlet_Identifier_x  \
# 0                   Dairy  249.8092              OUT049
# 1             Soft Drinks   48.2692              OUT018
# 2                    Meat  141.6180              OUT049
# 3   Fruits and Vegetables  182.0950              OUT010
# 4               Household   53.8614              OUT013
# ..                    ...       ...                 ...
# 95           Frozen Foods  120.0414              OUT019
# 96           Frozen Foods  246.0460              OUT049
# 97  Fruits and Vegetables  187.4556              OUT035
# 98              Household  149.9708              OUT027
# 99  Fruits and Vegetables  187.8556              OUT046
#
#     Outlet_Establishment_Year_x Outlet_Size_x Outlet_Location_Type_x  ...  \
# 0                          1999        Medium                 Tier 1  ...
# 1                          2009        Medium                 Tier 3  ...
# 2                          1999        Medium                 Tier 1  ...
# 3                          1998           NaN                 Tier 3  ...
# 4                          1987          High                 Tier 3  ...
# ..                          ...           ...                    ...  ...
# 95                         1985         Small                 Tier 1  ...
# 96                         1999        Medium                 Tier 1  ...
# 97                         2004         Small                 Tier 2  ...
# 98                         1985        Medium                 Tier 3  ...
# 99                         1997         Small                 Tier 1  ...
#
#    Item_Weight_y  Item_Fat_Content_y Item_Visibility_y  Item_Type_y  \
# 0            NaN                 NaN               NaN          NaN
# 1            NaN                 NaN               NaN          NaN
# 2            NaN                 NaN               NaN          NaN
# 3            NaN                 NaN               NaN          NaN
# 4            NaN                 NaN               NaN          NaN
# ..           ...                 ...               ...          ...
# 95           NaN                 NaN               NaN          NaN
# 96           NaN                 NaN               NaN          NaN
# 97           NaN                 NaN               NaN          NaN
# 98           NaN                 NaN               NaN          NaN
# 99           NaN                 NaN               NaN          NaN
#
#    Outlet_Identifier_y  Outlet_Establishment_Year_y Outlet_Size_y  \
# 0                  NaN                          NaN           NaN
# 1                  NaN                          NaN           NaN
# 2                  NaN                          NaN           NaN
# 3                  NaN                          NaN           NaN
# 4                  NaN                          NaN           NaN
# ..                 ...                          ...           ...
# 95                 NaN                          NaN           NaN
# 96                 NaN                          NaN           NaN
# 97                 NaN                          NaN           NaN
# 98                 NaN                          NaN           NaN
# 99                 NaN                          NaN           NaN
#
#    Outlet_Location_Type_y  Outlet_Type_y Item_Outlet_Sales_y
# 0                     NaN            NaN                 NaN
# 1                     NaN            NaN                 NaN
# 2                     NaN            NaN                 NaN
# 3                     NaN            NaN                 NaN
# 4                     NaN            NaN                 NaN
# ..                    ...            ...                 ...
# 95                    NaN            NaN                 NaN
# 96                    NaN            NaN                 NaN
# 97                    NaN            NaN                 NaN
# 98                    NaN            NaN                 NaN
# 99                    NaN            NaN                 NaN
#
# [100 rows x 23 columns]

# %%
# Merging dataframes with merge() and join='right'
combined_data8 = pd.merge(data_part1, data_part2, on='Item_MRP', how='right')
combined_data8
# Out:
#    Item_Identifier_x  Item_Weight_x Item_Fat_Content_x  Item_Visibility_x  \
# 0              FDV25          5.905            Low Fat                0.0
# 1                NaN            NaN                NaN                NaN
# 2                NaN            NaN                NaN                NaN
# 3                NaN            NaN                NaN                NaN
# 4                NaN            NaN                NaN                NaN
# ..               ...            ...                ...                ...
# 95               NaN            NaN                NaN                NaN
# 96               NaN            NaN                NaN                NaN
# 97               NaN            NaN                NaN                NaN
# 98               NaN            NaN                NaN                NaN
# 99               NaN            NaN                NaN                NaN
#
#    Item_Type_x  Item_MRP Outlet_Identifier_x  Outlet_Establishment_Year_x  \
# 0       Canned  222.5456              OUT045                       2002.0
# 1          NaN  151.0708                 NaN                          NaN
# 2          NaN  178.5344                 NaN                          NaN
# 3          NaN  179.1028                 NaN                          NaN
# 4          NaN   38.7822                 NaN                          NaN
# ..         ...       ...                 ...                          ...
# 95         NaN   37.6164                 NaN                          NaN
# 96         NaN   48.0718                 NaN                          NaN
# 97         NaN  238.8538                 NaN                          NaN
# 98         NaN   62.9194                 NaN                          NaN
# 99         NaN  232.6300                 NaN                          NaN
#
#    Outlet_Size_x Outlet_Location_Type_x  ... Item_Weight_y  \
# 0            NaN                 Tier 2  ...         5.905
# 1            NaN                    NaN  ...        13.300
# 2            NaN                    NaN  ...           NaN
# 3            NaN                    NaN  ...         8.310
# 4            NaN                    NaN  ...        16.750
# ..           ...                    ...  ...           ...
# 95           NaN                    NaN  ...        10.500
# 96           NaN                    NaN  ...        19.000
# 97           NaN                    NaN  ...        14.600
# 98           NaN                    NaN  ...           NaN
# 99           NaN                    NaN  ...           NaN
#
#     Item_Fat_Content_y Item_Visibility_y            Item_Type_y  \
# 0              Low Fat          0.045838                 Canned
# 1              Low Fat          0.063695           Frozen Foods
# 2              Regular          0.045798            Snack Foods
# 3              Regular          0.115857            Snack Foods
# 4              Regular          0.024833            Soft Drinks
# ..                 ...               ...                    ...
# 95             Low Fat          0.041395  Fruits and Vegetables
# 96             Regular          0.097313           Frozen Foods
# 97             Low Fat          0.059583                 Others
# 98             Regular          0.098664                  Dairy
# 99                 reg          0.101339                 Canned
#
#    Outlet_Identifier_y  Outlet_Establishment_Year_y Outlet_Size_y  \
# 0               OUT018                         2009        Medium
# 1               OUT045                         2002           NaN
# 2               OUT027                         1985        Medium
# 3               OUT049                         1999        Medium
# 4               OUT013                         1987          High
# ..                 ...                          ...           ...
# 95              OUT046                         1997         Small
# 96              OUT046                         1997         Small
# 97              OUT049                         1999        Medium
# 98              OUT027                         1985        Medium
# 99              OUT027                         1985        Medium
#
#    Outlet_Location_Type_y      Outlet_Type_y Item_Outlet_Sales_y
# 0                  Tier 3  Supermarket Type2           3315.6840
# 1                  Tier 2  Supermarket Type1           1805.6496
# 2                  Tier 3  Supermarket Type3           2854.9504
# 3                  Tier 1  Supermarket Type1           3896.2616
# 4                  Tier 3  Supermarket Type1            667.7974
# ..                    ...                ...                 ...
# 95                 Tier 1  Supermarket Type1            540.6296
# 96                 Tier 1  Supermarket Type1            992.7078
# 97                 Tier 1  Supermarket Type1           6008.8450
# 98                 Tier 3  Supermarket Type3           2105.2596
# 99                 Tier 3  Supermarket Type3           5359.6900
#
# [100 rows x 23 columns]
